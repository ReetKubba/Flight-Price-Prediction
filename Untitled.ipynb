# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Data_Train.csv')

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.duplicated().sum()
# Out:
# 220

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
df['Airline'].value_counts()
# Out:
# Jet Airways                          3700
# IndiGo                               2043
# Air India                            1695
# Multiple carriers                    1196
# SpiceJet                              815
# Vistara                               478
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %%
df=df[df['Airline']!='Trujet']

# %%
df=df[df['Airline']!='Vistara Premium economy']

# %%
df=df[df['Airline']!='Jet Airways Business']

# %%
df=df[df['Airline']!='Multiple carriers Premium economy']

# %%
df['Airline'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Airline'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Additional_Info'].value_counts()
# Out:
# No info                         8163
# In-flight meal not included     1926
# No check-in baggage included     318
# 1 Long layover                    19
# Change airports                    7
# No Info                            3
# 1 Short layover                    1
# Business class                     1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64

# %%
df=df[df['Additional_Info']!='2 Long layover']

# %%
df=df[df['Additional_Info']!='Red-eye flight']

# %%
df=df[df['Additional_Info']!='Business class']

# %%
df=df[df['Additional_Info']!='1 Short layover']

# %%
df=df[df['Additional_Info']!='No Info']

# %%
df=df[df['Additional_Info']!='Change airports']

# %%
df['Additional_Info'].value_counts()
# Out:
# No info                         8163
# In-flight meal not included     1926
# No check-in baggage included     318
# 1 Long layover                    19
# Name: Additional_Info, dtype: int64

# %%
df[["day", "month", "year"]] = df["Date_of_Journey"].str.split("/", expand = True)

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price day  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897  24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662   1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882   9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218  12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302  01
#
#   month  year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# ...

# %%
df.drop(df.columns[[1,13]], axis=1, inplace=True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR ? DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL ? LKO ? BOM ? COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU ? NAG ? BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR ? NAG ? DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price day month
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897  24    03
# 1         13:15   7h 25m     2 stops         No info   7662   1    05
# 2  04:25 10 Jun      19h     2 stops         No info  13882   9    06
# 3         23:30   5h 25m      1 stop         No info   6218  12    05
# 4         21:35   4h 45m      1 stop         No info  13302  01    03

# %%
df['day'] = df['day'].astype(int)

# %%
df['month'] = df['month'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10426 entries, 0 to 10682
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10426 non-null  object
#  1   Source           10426 non-null  object
#  2   Destination      10426 non-null  object
#  3   Route            10425 non-null  object
#  4   Dep_Time         10426 non-null  object
#  5   Arrival_Time     10426 non-null  object
#  6   Duration         10426 non-null  object
#  7   Total_Stops      10425 non-null  object
#  8   Additional_Info  10426 non-null  object
#  9   Price            10426 non-null  int64
#  10  day              10426 non-null  int32
#  11  month            10426 non-null  int32
# dtypes: int32(2), int64(1), object(9)
# memory usage: 977.4+ KB

# %%
df['Total_Stops']=df['Total_Stops'].replace("non-stop","0 stop")

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR ? DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL ? LKO ? BOM ? COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU ? NAG ? BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR ? NAG ? DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  day  month
# 0  01:10 22 Mar   2h 50m      0 stop         No info   3897   24      3
# 1         13:15   7h 25m     2 stops         No info   7662    1      5
# 2  04:25 10 Jun      19h     2 stops         No info  13882    9      6
# 3         23:30   5h 25m      1 stop         No info   6218   12      5
# 4         21:35   4h 45m      1 stop         No info  13302    1      3

# %%
df['Total_Stops'].value_counts()
# Out:
# 1 stop     5601
# 0 stop     3471
# 2 stops    1310
# 3 stops      43
# Name: Total_Stops, dtype: int64

# %%
df=df[df['Total_Stops']!='4 stops']

# %%
df['Total_Stops'].value_counts()
# Out:
# 1 stop     5601
# 0 stop     3471
# 2 stops    1310
# 3 stops      43
# Name: Total_Stops, dtype: int64

# %%
df['Total_Stops'] = df['Total_Stops'].str[0]

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR ? DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL ? LKO ? BOM ? COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU ? NAG ? BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR ? NAG ? DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  day  month
# 0  01:10 22 Mar   2h 50m           0         No info   3897   24      3
# 1         13:15   7h 25m           2         No info   7662    1      5
# 2  04:25 10 Jun      19h           2         No info  13882    9      6
# 3         23:30   5h 25m           1         No info   6218   12      5
# 4         21:35   4h 45m           1         No info  13302    1      3

# %%
df = df.dropna()

# %%
df['Total_Stops']=df['Total_Stops'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10425 entries, 0 to 10682
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10425 non-null  object
#  1   Source           10425 non-null  object
#  2   Destination      10425 non-null  object
#  3   Route            10425 non-null  object
#  4   Dep_Time         10425 non-null  object
#  5   Arrival_Time     10425 non-null  object
#  6   Duration         10425 non-null  object
#  7   Total_Stops      10425 non-null  int32
#  8   Additional_Info  10425 non-null  object
#  9   Price            10425 non-null  int64
#  10  day              10425 non-null  int32
#  11  month            10425 non-null  int32
# dtypes: int32(3), int64(1), object(8)
# memory usage: 936.6+ KB

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR ? DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL ? LKO ? BOM ? COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU ? NAG ? BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR ? NAG ? DEL    16:50
#
#    Arrival_Time Duration  Total_Stops Additional_Info  Price  day  month
# 0  01:10 22 Mar   2h 50m            0         No info   3897   24      3
# 1         13:15   7h 25m            2         No info   7662    1      5
# 2  04:25 10 Jun      19h            2         No info  13882    9      6
# 3         23:30   5h 25m            1         No info   6218   12      5
# 4         21:35   4h 45m            1         No info  13302    1      3

# %%
def get_duration(x):
    x=x.split(' ')
    hours=0
    mins=0
    if len(x)==1:
        x=x[0]
        if x[-1]=='h':
            hours=int(x[:-1])
        else:
            mins=int(x[:-1])
    else:
        hours=int(x[0][:-1])
        mins=int(x[1][:-1])
    return hours,mins
df['Duration_hours']=df.Duration.apply(lambda x:get_duration(x)[0])
df['Duration_mins']=df.Duration.apply(lambda x:get_duration(x)[1])
df.drop(["Duration"], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10425 entries, 0 to 10682
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10425 non-null  object
#  1   Source           10425 non-null  object
#  2   Destination      10425 non-null  object
#  3   Route            10425 non-null  object
#  4   Dep_Time         10425 non-null  object
#  5   Arrival_Time     10425 non-null  object
#  6   Total_Stops      10425 non-null  int32
#  7   Additional_Info  10425 non-null  object
#  8   Price            10425 non-null  int64
#  9   day              10425 non-null  int32
#  10  month            10425 non-null  int32
#  11  Duration_hours   10425 non-null  int64
#  12  Duration_mins    10425 non-null  int64
# dtypes: int32(3), int64(3), object(7)
# memory usage: 1018.1+ KB

# %%
df.sample(40)
# Out:
#                  Airline    Source Destination                        Route  \
# 1217         Jet Airways     Delhi      Cochin              DEL ? BOM ? COK
# 7505             Vistara     Delhi      Cochin                    DEL ? COK
# 557            Air India  Banglore       Delhi                    BLR ? DEL
# 8711         Jet Airways     Delhi      Cochin              DEL ? BOM ? COK
# 10473          Air India   Kolkata    Banglore        CCU ? BBI ? BOM ? BLR
# 9341         Jet Airways    Mumbai   Hyderabad                    BOM ? HYD
# 2967         Jet Airways   Kolkata    Banglore              CCU ? BOM ? BLR
# 2549           Air India  Banglore   New Delhi              BLR ? BOM ? DEL
# 1597           Air India  Banglore   New Delhi                    BLR ? DEL
# 4341         Jet Airways     Delhi      Cochin        DEL ? AMD ? BOM ? COK
# 1763            SpiceJet   Kolkata    Banglore                    CCU ? BLR
# ...

# %%
df[["Dep_time_hr", "Dep_time_min"]] = df["Dep_Time"].str.split(":", expand = True)

# %%
df.sample(50)
# Out:
#                  Airline    Source Destination                        Route  \
# 8649            Air Asia  Banglore       Delhi                    BLR ? DEL
# 4485              IndiGo     Delhi      Cochin              DEL ? HYD ? COK
# 8595   Multiple carriers     Delhi      Cochin              DEL ? BOM ? COK
# 6268         Jet Airways     Delhi      Cochin        DEL ? JAI ? BOM ? COK
# 4616              IndiGo  Banglore       Delhi                    BLR ? DEL
# 7847         Jet Airways   Kolkata    Banglore              CCU ? BOM ? BLR
# 1027              IndiGo  Banglore       Delhi                    BLR ? DEL
# 4618           Air India   Kolkata    Banglore        CCU ? IXR ? DEL ? BLR
# 3911               GoAir  Banglore   New Delhi                    BLR ? DEL
# 6678   Multiple carriers     Delhi      Cochin              DEL ? BOM ? COK
# 2847         Jet Airways   Kolkata    Banglore              CCU ? BOM ? BLR
# ...

# %%
df[["Arr_time_hr", "Arr_time_min"]] = df["Dep_Time"].str.split(":", expand = True)

# %%
df.sample(50)
# Out:
#                  Airline    Source Destination                  Route  \
# 151          Jet Airways     Delhi      Cochin  DEL ? BDQ ? BOM ? COK
# 5791              IndiGo     Delhi      Cochin        DEL ? BOM ? COK
# 3286           Air India   Kolkata    Banglore        CCU ? BOM ? BLR
# 4236           Air India   Kolkata    Banglore  CCU ? BOM ? COK ? BLR
# 5604              IndiGo     Delhi      Cochin        DEL ? HYD ? COK
# 7152           Air India   Kolkata    Banglore        CCU ? DEL ? BLR
# 1696            SpiceJet     Delhi      Cochin        DEL ? BLR ? COK
# 12             Air India   Chennai     Kolkata              MAA ? CCU
# 6192         Jet Airways     Delhi      Cochin  DEL ? BDQ ? BOM ? COK
# 5679           Air India  Banglore   New Delhi  BLR ? BOM ? NAG ? DEL
# 4219           Air India  Banglore       Delhi              BLR ? DEL
# 9141             Vistara  Banglore       Delhi              BLR ? DEL
# ...

# %%
df.drop(["Arrival_Time"], axis = 1, inplace = True)

# %%
df.drop(["Dep_Time"], axis = 1, inplace = True)

# %%
df.sample(40)
# Out:
#                  Airline    Source Destination                  Route  \
# 1972            Air Asia     Delhi      Cochin        DEL ? BLR ? COK
# 4298         Jet Airways   Kolkata    Banglore        CCU ? BOM ? BLR
# 7225         Jet Airways   Kolkata    Banglore        CCU ? DEL ? BLR
# 4148               GoAir  Banglore       Delhi              BLR ? DEL
# 9341         Jet Airways    Mumbai   Hyderabad              BOM ? HYD
# 6237              IndiGo   Kolkata    Banglore              CCU ? BLR
# 7640         Jet Airways   Kolkata    Banglore        CCU ? BOM ? BLR
# 9393           Air India  Banglore       Delhi              BLR ? DEL
# 526          Jet Airways     Delhi      Cochin        DEL ? BOM ? COK
# 6453              IndiGo    Mumbai   Hyderabad              BOM ? HYD
# 3392         Jet Airways   Kolkata    Banglore        CCU ? BOM ? BLR
# 8879              IndiGo   Kolkata    Banglore              CCU ? BLR
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10425 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10425 non-null  object
#  1   Source           10425 non-null  object
#  2   Destination      10425 non-null  object
#  3   Route            10425 non-null  object
#  4   Total_Stops      10425 non-null  int32
#  5   Additional_Info  10425 non-null  object
#  6   Price            10425 non-null  int64
#  7   day              10425 non-null  int32
#  8   month            10425 non-null  int32
#  9   Duration_hours   10425 non-null  int64
#  10  Duration_mins    10425 non-null  int64
#  11  Dep_time_hr      10425 non-null  object
#  12  Dep_time_min     10425 non-null  object
#  13  Arr_time_hr      10425 non-null  object
#  14  Arr_time_min     10425 non-null  object
# dtypes: int32(3), int64(3), object(9)
# memory usage: 1.2+ MB

# %%
df['Dep_time_hr']=df['Dep_time_hr'].astype(int)
df['Dep_time_min']=df['Dep_time_min'].astype(int)

# %%
df['Arr_time_hr']=df['Dep_time_hr'].astype(int)
df['Arr_time_min']=df['Dep_time_min'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10425 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10425 non-null  object
#  1   Source           10425 non-null  object
#  2   Destination      10425 non-null  object
#  3   Route            10425 non-null  object
#  4   Total_Stops      10425 non-null  int32
#  5   Additional_Info  10425 non-null  object
#  6   Price            10425 non-null  int64
#  7   day              10425 non-null  int32
#  8   month            10425 non-null  int32
#  9   Duration_hours   10425 non-null  int64
#  10  Duration_mins    10425 non-null  int64
#  11  Dep_time_hr      10425 non-null  int32
#  12  Dep_time_min     10425 non-null  int32
#  13  Arr_time_hr      10425 non-null  int32
#  14  Arr_time_min     10425 non-null  int32
# dtypes: int32(7), int64(3), object(5)
# memory usage: 1018.1+ KB

# %%
df['Duration_bool'] = (df['Duration_hours']*60)+df['Duration_mins']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10425 entries, 0 to 10682
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10425 non-null  object
#  1   Source           10425 non-null  object
#  2   Destination      10425 non-null  object
#  3   Route            10425 non-null  object
#  4   Total_Stops      10425 non-null  int32
#  5   Additional_Info  10425 non-null  object
#  6   Price            10425 non-null  int64
#  7   day              10425 non-null  int32
#  8   month            10425 non-null  int32
#  9   Duration_hours   10425 non-null  int64
#  10  Duration_mins    10425 non-null  int64
#  11  Dep_time_hr      10425 non-null  int32
#  12  Dep_time_min     10425 non-null  int32
#  13  Arr_time_hr      10425 non-null  int32
#  14  Arr_time_min     10425 non-null  int32
#  15  Duration_bool    10425 non-null  int64
# dtypes: int32(7), int64(4), object(5)
# ...

# %%
df.drop(["Duration_hours"], axis = 1, inplace = True)
df.drop(["Duration_mins"], axis = 1, inplace = True)

# %%
df.drop(["Route"], axis = 1, inplace = True)

# %%
df.sample(40)
# Out:
#                  Airline    Source Destination  Total_Stops  \
# 6409           Air India    Mumbai   Hyderabad            0
# 6539         Jet Airways    Mumbai   Hyderabad            0
# 8671           Air India   Kolkata    Banglore            2
# 3097            Air Asia     Delhi      Cochin            1
# 503            Air India     Delhi      Cochin            1
# 3605         Jet Airways     Delhi      Cochin            2
# 5173              IndiGo  Banglore       Delhi            0
# 8100         Jet Airways     Delhi      Cochin            2
# 4766         Jet Airways   Kolkata    Banglore            1
# 1926            SpiceJet  Banglore       Delhi            0
# 10162             IndiGo  Banglore   New Delhi            0
# 6061   Multiple carriers     Delhi      Cochin            1
# 3304           Air India  Banglore   New Delhi            2
# 6101         Jet Airways  Banglore       Delhi            0
# 2769              IndiGo     Delhi      Cochin            1
# ...

# %%
df.corr()['Price']
# Out:
# Total_Stops      0.619852
# Price            1.000000
# day             -0.154485
# month           -0.104743
# Dep_time_hr      0.010726
# Dep_time_min    -0.030563
# Arr_time_hr      0.010726
# Arr_time_min    -0.030563
# Duration_bool    0.524243
# Name: Price, dtype: float64

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
X=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
X
# Out:
#            Airline    Source Destination  Total_Stops Additional_Info  day  \
# 0           IndiGo  Banglore   New Delhi            0         No info   24
# 1        Air India   Kolkata    Banglore            2         No info    1
# 2      Jet Airways     Delhi      Cochin            2         No info    9
# 3           IndiGo   Kolkata    Banglore            1         No info   12
# 4           IndiGo  Banglore   New Delhi            1         No info    1
# ...            ...       ...         ...          ...             ...  ...
# 10678     Air Asia   Kolkata    Banglore            0         No info    9
# 10679    Air India   Kolkata    Banglore            0         No info   27
# 10680  Jet Airways  Banglore       Delhi            0         No info   27
# 10681      Vistara  Banglore   New Delhi            0         No info    1
# 10682    Air India     Delhi      Cochin            2         No info    9
#
# ...

# %%
y
# Out:
# 0        8.267962
# 1        8.944028
# 2        9.538348
# 3        8.735204
# 4        9.495670
#            ...
# 10678    8.320448
# 10679    8.329658
# 10680    8.885856
# 10681    9.445254
# 10682    9.371864
# Name: Price, Length: 10425, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#                 Airline    Source Destination  Total_Stops  \
# 1353          Air India  Banglore   New Delhi            2
# 6066  Multiple carriers     Delhi      Cochin            1
# 5565        Jet Airways   Kolkata    Banglore            1
# 4883  Multiple carriers     Delhi      Cochin            1
# 9022        Jet Airways   Kolkata    Banglore            1
# ...                 ...       ...         ...          ...
# 1106        Jet Airways   Kolkata    Banglore            1
# 2534  Multiple carriers     Delhi      Cochin            1
# 6741             IndiGo     Delhi      Cochin            1
# 2597        Jet Airways   Kolkata    Banglore            1
# 7458  Multiple carriers     Delhi      Cochin            1
#
#                   Additional_Info  day  month  Dep_time_hr  Dep_time_min  \
# 1353                      No info    1      3            6            45
# 6066                      No info   21      3            7             0
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline 
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
#Linear Regression
step1=ColumnTransformer(transformers=[
    ('encoder',OneHotEncoder(),[0,1,2,4])
],remainder='passthrough')
step2=LinearRegression()
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7616606587483388
# MAE 0.19092468410513652

# %%
#Decision Tree
step1=ColumnTransformer(transformers=[
    ('encoder',OneHotEncoder(),[0,1,2,4])
],remainder='passthrough')
step2=DecisionTreeRegressor(max_depth=8)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8805160176036636
# MAE 0.11793481575096036

# %%
#SVM
step1=ColumnTransformer(transformers=[
    ('encoder',OneHotEncoder(),[0,1,2,4])
],remainder='passthrough')
step2=SVR(kernel='rbf',C=10000,epsilon=0.1)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7967745832623016
# MAE 0.16777648917745613

# %%
#Random Forest
step1=ColumnTransformer(transformers=[
    ('encoder',OneHotEncoder(),[0,1,2,4])
],remainder='passthrough')
step2=RandomForestRegressor(n_estimators=100,
                           random_state=3,
                           max_samples=0.5,
                           max_features=0.75,
                           max_depth=15)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.9326676010082999
# MAE 0.08172753232421247

# %%
#Exporting the model
import pickle
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))
